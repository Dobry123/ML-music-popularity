# %% [markdown]
# # Projekt Zespołowy - ZMUM
# ## Analiza popularności muzyki na podstawie jej cech

# %% [markdown]
# **Autorzy**:
# >Michał Kiełczykowski 284240
# >Edward Sucharda 284388
# >Mateusz Szczygielski 284266

# %% [markdown]
# ### Analizowany zbiór
# Jako dane wykorzystano zbiór utworów muzycznych, które można znaleźć na kanale Spotify. Muzyka jest pochodzi z okresu 1921-2020. Dane otrzymano ze strony https://www.kaggle.com/yamaerenay/spotify-dataset-19212020-160k-tracks?select=data.csv

# %% [markdown]
# ### Przygotowanie danych

# %%
import pandas as pd
import numpy as np
import seaborn as sn
import matplotlib.pyplot as plt
import sklearn
from datetime import datetime as dt
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn import linear_model
from sklearn.model_selection import cross_validate, cross_val_score
from sklearn.linear_model import LinearRegression

# %%
music = pd.read_csv('data.csv')
music.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 174389 entries, 0 to 174388
# Data columns (total 19 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   acousticness      174389 non-null  float64
#  1   artists           174389 non-null  object
#  2   danceability      174389 non-null  float64
#  3   duration_ms       174389 non-null  int64
#  4   energy            174389 non-null  float64
#  5   explicit          174389 non-null  int64
#  6   id                174389 non-null  object
#  7   instrumentalness  174389 non-null  float64
#  8   key               174389 non-null  int64
#  9   liveness          174389 non-null  float64
#  10  loudness          174389 non-null  float64
#  11  mode              174389 non-null  int64
#  12  name              174389 non-null  object
#  13  popularity        174389 non-null  int64
#  14  release_date      174389 non-null  object
#  15  speechiness       174389 non-null  float64
#  16  tempo             174389 non-null  float64
#  17  valence           174389 non-null  float64
#  18  year              174389 non-null  int64
# dtypes: float64(9), int64(6), object(4)
# memory usage: 25.3+ MB

# %% [markdown]
# #### Opis danych:
# | name        | descrpition |
# |:-------------|:-------------------|
#  acousticness: |  The relative metric of the track being acoustic <0, 1>
# artists: | The list of artists credited for production of the track
# danceability: | The relative measurement of the track being danceable <0,1>
# duration_ms: | The length of the track in milliseconds (ms)
# energy: | The energy of the track <0,1>
# explicit: | 0 = No explicit content, 1 = Explicit content
# id: | Id of track generated by Spotify
# instrumentalness: | The relative ratio of the track being instrumental <0,1>
# key: | All keys on octave encoded as values ranging from 0 to 11, starting on C as 0, C# as 1 and so on…
# loudness: | Relative loudness of the track in the typical range <-60, 0> in decibel (dB)
# mode: | The binary value representing whether the track starts with a major (1) chord progression or not (0)
# name: | The title of the track
# popularity: | The popularity of the song lately, default country = US, <0,100>
# release_date: | Date of release mostly in yyyy-mm-dd format, however precision of date may vary
# speechiness: | The relative length of the track containing any kind of human voice
# tempo: | The tempo of the track in Beat Per Minute (BPM)
# valence: | The relative duration of the track sounding as a live performance, <0,1>
# year: | The release year of track

# %% [markdown]
# Sprawdzenie czy można pozbyć się kolumny *year*, która zawiera w sobie informacje z kolumny *release_date*

# %%
music['str_year'] = music['year'].apply(lambda x: str(x))
no_exact_realaese_date = np.where(music['str_year'] == music['release_date'], 1, 0)
print("Liczba danych:", no_exact_realaese_date.sum())
# Out:
# Liczba danych: 50819

# %%
music['release_date'].head(10)
# Out:
# 0          1920
# 1    1920-01-05
# 2          1920
# 3    1920-01-01
# 4    1920-10-01
# 5          1920
# 6          1920
# 7          1920
# 8    1920-07-08
# 9    1920-01-01
# Name: release_date, dtype: object

# %% [markdown]
# Lepiej pozbyć się kolumny *release_date*, gdyż zbyt dużo danych ma niedokładną datę (tylko sam rok). Przy okazaji można się pozbyć *id* i *str_year* które nie wnoszą nowych informacji oraz *name* i *artist*, które nie sposób sensowanie zakodować liczbowo.

# %%
music = music.drop(['id', 'name', 'artists', 'str_year', 'release_date'], axis = 1)

# %%
music.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 174389 entries, 0 to 174388
# Data columns (total 15 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   acousticness      174389 non-null  float64
#  1   danceability      174389 non-null  float64
#  2   duration_ms       174389 non-null  int64
#  3   energy            174389 non-null  float64
#  4   explicit          174389 non-null  int64
#  5   instrumentalness  174389 non-null  float64
#  6   key               174389 non-null  int64
#  7   liveness          174389 non-null  float64
#  8   loudness          174389 non-null  float64
#  9   mode              174389 non-null  int64
#  10  popularity        174389 non-null  int64
#  11  speechiness       174389 non-null  float64
#  12  tempo             174389 non-null  float64
#  13  valence           174389 non-null  float64
#  14  year              174389 non-null  int64
# dtypes: float64(9), int64(6)
# memory usage: 20.0 MB

# %%
properties = music.describe()
properties.loc['skewness'] = music.skew()
properties.loc['median'] = music.median()
properties.loc['mode'] = music.mode().iloc[0]
properties.loc['variance'] = music.var()
properties.loc['kurtosis'] = music.kurtosis()

# %%
properties
# Out:
#            acousticness   danceability   duration_ms         energy  \
# count     174389.000000  174389.000000  1.743890e+05  174389.000000
# mean           0.499228       0.536758  2.328100e+05       0.482721
# std            0.379936       0.176025  1.483958e+05       0.272685
# min            0.000000       0.000000  4.937000e+03       0.000000
# 25%            0.087700       0.414000  1.661330e+05       0.249000
# 50%            0.517000       0.548000  2.057870e+05       0.465000
# 75%            0.895000       0.669000  2.657200e+05       0.711000
# max            0.996000       0.988000  5.338302e+06       1.000000
# skewness      -0.034518      -0.236234  1.015938e+01       0.144279
# median         0.517000       0.548000  2.057870e+05       0.465000
# mode           0.995000       0.565000  1.500000e+05       0.195000
# variance       0.144351       0.030985  2.202131e+10       0.074357
# kurtosis      -1.620262      -0.469464  2.166659e+02      -1.124219
#
#                explicit  instrumentalness            key       liveness  \
# count     174389.000000     174389.000000  174389.000000  174389.000000
# mean           0.068135          0.197252       5.205305       0.211123
# std            0.251978          0.334574       3.518292       0.180493
# min            0.000000          0.000000       0.000000       0.000000
# 25%            0.000000          0.000000       2.000000       0.099200
# 50%            0.000000          0.000524       5.000000       0.138000
# 75%            0.000000          0.252000       8.000000       0.270000
# max            1.000000          1.000000      11.000000       1.000000
# skewness       3.427836          1.363704       0.003932       2.078374
# median         0.000000          0.000524       5.000000       0.138000
# mode           0.000000          0.000000       0.000000       0.111000
# variance       0.063493          0.111940      12.378377       0.032578
# kurtosis       9.750169          0.100842      -1.272034       4.495866
#
#                loudness           mode     popularity    speechiness  \
# count     174389.000000  174389.000000  174389.000000  174389.000000
# mean         -11.750865       0.702384      25.693381       0.105729
# std            5.691591       0.457211      21.872740       0.182260
# min          -60.000000       0.000000       0.000000       0.000000
# 25%          -14.908000       0.000000       1.000000       0.035200
# 50%          -10.836000       1.000000      25.000000       0.045500
# 75%           -7.499000       1.000000      42.000000       0.076300
# max            3.855000       1.000000     100.000000       0.971000
# skewness      -0.989120      -0.885307       0.362937       3.750971
# median       -10.836000       1.000000      25.000000       0.045500
# mode          -7.578000       1.000000       0.000000       0.033700
# variance      32.394206       0.209042     478.416748       0.033219
# kurtosis       1.491533      -1.216246      -0.946212      13.776655
#
#                   tempo        valence           year
# count     174389.000000  174389.000000  174389.000000
# mean         117.006500       0.524533    1977.061764
# std           30.254178       0.264477      26.907950
# min            0.000000       0.000000    1920.000000
# 25%           93.931000       0.311000    1955.000000
# 50%          115.816000       0.536000    1977.000000
# 75%          135.011000       0.743000    1999.000000
# max          243.507000       1.000000    2021.000000
# skewness       0.423394      -0.100729      -0.080966
# median       115.816000       0.536000    1977.000000
# mode           0.000000       0.961000    2020.000000
# variance     915.315288       0.069948     724.037788
# kurtosis      -0.036621      -1.069433      -1.050776

# %% [markdown]
# #### Reprezentacja wizualna danych
#
# Histogramy zmiennych

# %%
plt.figure(figsize=(15,5*len(music.columns.values)))
for i, column in enumerate(music):
    plt.subplot(len(music.columns.values), 3, i+1)
    plt.title(column)
    plt.hist(music[column], bins = min(len(music[column].unique()), 10))

# %% [markdown]
# Po analizie histogramów usuwamy dane odstające czyli te dla których *loudness* < -40 oraz te gdzie *duration_ms* > 2000000

# %%
music = music.drop(music[(music['duration_ms'] > 2000000) | (music['loudness'] < -40)].index, axis = 0)

# %% [markdown]
# Liczba próbek po usunięciu:

# %%
music.shape[0]
# Out:
# 174158

# %% [markdown]
# Po usunięciu 231 próbek pozostało nadal 174158 próbek, czyli wystarczająco aby uzyskać wiarygodne wyniki estymacji.
#
# Wygląd histogramów po usunięciu danych odstających

# %%
plt.figure(figsize=(15,5*len(music.columns.values)))
for i, column in enumerate(music):
    plt.subplot(len(music.columns.values), 3, i+1)
    plt.title(column)
    plt.hist(music[column], bins = min(len(music[column].unique()), 10))

# %% [markdown]
# #### Analiza korelacji zmiennych
#
# Wyliczenie macierzy korelacji

# %%
plt.figure(figsize=(20,20), dpi = 80)
corelation_matrix = music.corr()
sn.heatmap(corelation_matrix ,annot = music.corr())

# %% [markdown]
# Wzajemna korelacja cech wejściowych:

# %%
print("Cecha 1\tCecha 2\tWspółczynnik korelacji\n")
for index, row in corelation_matrix.iterrows():
    for (columnName, columnData) in corelation_matrix.iteritems():
        if index != columnName:
            if abs(columnData[index]) >= 0.5:
                print(columnName, index, abs(columnData[index]))
# Out:
# Cecha 1	Cecha 2	Współczynnik korelacji
#
# energy acousticness 0.750984991608878
# loudness acousticness 0.5492994262301776
# year acousticness 0.6077160887667816
# valence danceability 0.5360085738330125
# acousticness energy 0.750984991608878
# loudness energy 0.7815716957551477
# year energy 0.5410512961205374
# acousticness loudness 0.5492994262301776
# energy loudness 0.7815716957551477
# year popularity 0.5140617929652019
# danceability valence 0.5360085738330125
# acousticness year 0.6077160887667816
# energy year 0.5410512961205374
# popularity year 0.5140617929652019

# %% [markdown]
# Najwięcej cech skorelowanych mają *acousticness*, *year*, i *energy*. Postanowiono zbadać wyniki prostej regresji wielorakiej z dotychczaowych cech, żeby sprawdzić badanie, której wielkości ma największy sens.

# %% [markdown]
# Poniżej funckja wynaczająca błąd na danych treningowych i testowych, dla parametru estymowanego jako argument funkcji.

# %%
def conut_error(estimated_feature):
    all_features_data = music.drop([estimated_feature], axis = 1)
    X_train, X_test, y_train, y_test = train_test_split(all_features_data, music[estimated_feature], test_size=0.33, random_state=1)
    X_pinv = np.linalg.pinv(X_train)
    ω = np.dot(X_pinv, y_train)
    y_pred_train = np.dot(X_train, ω)
    train_error = mean_squared_error(y_train, y_pred_train, squared=False)
    y_pred_test = np.dot(X_test, ω)
    test_error = mean_squared_error(y_test, y_pred_test, squared=False)
    print('Train error: ' + str(train_error), ", Test error: " + str(test_error))

# %%
conut_error('energy')
# Out:
# Train error: 0.12138821084671461 , Test error: 0.12047871592426257

# %%
conut_error('year')
# Out:
# Train error: 182.48626810512988 , Test error: 182.1093032395839

# %%
conut_error('acousticness')
# Out:
# Train error: 0.22864406785491692 , Test error: 0.22728227282805957

# %% [markdown]
# Rozkład cechy *year* zawiera się w przedziale <1920, 2020>. Biorąc pod uwagę fakt, że pozostałe, analizowane cechy są znormalizowane do przedziału <0,1> oraz ich wartość błędu jest proporcjonalnie mniejsza, cecha energy została wybrana jako główny obszar analizy problemu badawczego. Na podstawie tej analizy postawiono następującą **hipotezę badawczą**:

# %% [markdown]
# ### *H0: Istnieje możliwość szacowania energii muzyki na podstawie jej cech.*

# %% [markdown]
# cechy najbardziej skolerowane z *energy* to:

# %%
corelated_features = []
for index, row in corelation_matrix.iterrows():
    if abs(row['energy']) > 0.5 and index != 'energy':
        corelated_features.append(index)
print(corelated_features)
# Out:
# ['acousticness', 'loudness', 'year']

# %% [markdown]
# Zbadano także cechy inne niż *energy*, które są skorelowane między sobą.

# %%
for index, row in corelation_matrix.iterrows():
    for (columnName, columnData) in corelation_matrix.iteritems():
        if index != 'energy' and columnName != 'energy' and index != columnName:
            if abs(columnData[index]) >= 0.5:
                print(columnName, index, abs(columnData[index]))
# Out:
# loudness acousticness 0.5492994262301776
# year acousticness 0.6077160887667816
# valence danceability 0.5360085738330125
# acousticness loudness 0.5492994262301776
# year popularity 0.5140617929652019
# danceability valence 0.5360085738330125
# acousticness year 0.6077160887667816
# popularity year 0.5140617929652019

# %% [markdown]
# ### Wnioski wynikające z analizy danych:
# * próbek jest dużo więcej niż cech, więc da się jednoznacznie wyznaczyć najlepsze dopasowanie dla wszystkich cech
# * występują cechy skorelowane z wyjściem co sugeruje, że istnieje potencjał badawczy wyznaczania zależności między cechami a energią
# * niektóre cechy są skorelowane ze sobą i prawdopodobnie dobrze byłoby, którąś z każdej pary odrzucić albo wykorzystać do wytworzenia nowej cechy
# * najbardziej skorelowane cechy z energią to kandydaci dla których współczynniki regresji linowej będą największe

# %% [markdown]
# ## Tworzenie nowych cech

# %% [markdown]
# Na podstawie zauważonych prawych skośności dla cech:
# * *instrumentalness*
# * *liveness*
# * *speechiness*
#
# Stworzono nowe cechy, w których jest ona niwelowana.

# %%
old_features = ['instrumentalness', 'liveness', 'speechiness']
new_features = ['log_instrumentalness', 'log_liveness', 'log_speechiness']
music['log_instrumentalness'] = music['instrumentalness'].apply(lambda x: np.log(x+1))
music['log_liveness'] = music['liveness'].apply(lambda x: np.log(x+1))
music['log_speechiness'] = music['speechiness'].apply(lambda x: np.log(x+1))

# %%
plt.figure(figsize=(15,5*len(old_features)))
for i, column in enumerate(old_features):
    plt.subplot(len(old_features), 2, 2*i+1)
    plt.title(old_features[i])
    plt.hist(music[old_features[i]], bins = min(len(music[old_features[i]].unique()), 10))
    
    plt.subplot(len(old_features), 2, 2*i+2)
    plt.title(new_features[i])
    plt.hist(music[new_features[i]], bins = min(len(music[new_features[i]].unique()), 10))

# %%
for i, column in enumerate(old_features):
    print("{} - skew: {}".format(old_features[i], music[old_features[i]].skew()))
    print("{} - skew: {}".format(new_features[i], music[new_features[i]].skew()))
    print("---")
# Out:
# instrumentalness - skew: 1.3663733881603026
# log_instrumentalness - skew: 1.2838020326226074
# ---
# liveness - skew: 2.078289393315535
# log_liveness - skew: 1.6900634833126753
# ---
# speechiness - skew: 3.751178535300461
# log_speechiness - skew: 3.4047836019198865
# ---

# %% [markdown]
# Nowe cechy poprawiły prawoskośność oryginalnych cech

# %% [markdown]
# Próbowano też różnych kombinacji cech, które są choć trochę skorelowane

# %%
corelated_features = []
for index, row in corelation_matrix.iterrows():
    if abs(row['energy']) > 0.3 and index != 'energy':
        corelated_features.append(index)
print(corelated_features)
# Out:
# ['acousticness', 'loudness', 'popularity', 'valence', 'year']

# %% [markdown]
# Ostatecznie wygenerowano szereg cech, na podstawie których wyznaczono macierz korelacji nowych cech z wyjściem

# %%
features = music.drop(['energy'], axis = 1)
basic_features = features.columns.values
corelated_features2 = []
for name in corelated_features:
    music['cube_'+ name] = music[name].apply(lambda x: x ** 3)
    music['square_'+ name] = music[name].apply(lambda x: x ** 2)
    new_features.append('cube_'+ name)
    new_features.append('square_'+ name)
    for element in corelated_features2:
        music[name + '_times_' + element] = music[name]*music[element]
        new_features.append(name + '_times_' + element)
    corelated_features2.append(name)

# %%
new_features_plus_output = new_features.copy()
new_features_plus_output.append('energy')
new_features_data = music[new_features_plus_output]
plt.figure(figsize=(15,15), dpi = 80)
sn.heatmap(new_features_data.corr(), annot = new_features_data.corr())

# %%
# połączenie nowych cech ze starymi
music.head()
# Out:
#    acousticness  danceability  duration_ms  energy  explicit  \
# 0      0.991000         0.598       168333   0.224         0
# 1      0.643000         0.852       150200   0.517         0
# 2      0.993000         0.647       163827   0.186         0
# 3      0.000173         0.730       422087   0.798         0
# 4      0.295000         0.704       165224   0.707         1
#
#    instrumentalness  key  liveness  loudness  mode  ...  square_valence  \
# 0          0.000522    5    0.3790   -12.628     0  ...        0.401956
# 1          0.026400    5    0.0809    -7.261     0  ...        0.902500
# 2          0.000018    0    0.5190   -12.098     1  ...        0.474721
# 3          0.801000    2    0.1280    -7.311     1  ...        0.001781
# 4          0.000246   10    0.4020    -6.036     0  ...        0.089401
#
#    valence_times_acousticness  valence_times_loudness  \
# 0                    0.628294               -8.006152
# 1                    0.610850               -6.897950
# 2                    0.684177               -8.335522
# 3                    0.000007               -0.308524
# 4                    0.088205               -1.804764
#
#    valence_times_popularity   cube_year  square_year  year_times_acousticness  \
# 0                    7.6080  7077888000      3686400               1902.72000
# 1                    6.6500  7077888000      3686400               1234.56000
# 2                    2.7560  7077888000      3686400               1906.56000
# 3                    0.7174  7077888000      3686400                  0.33216
# 4                    0.5980  7077888000      3686400                566.40000
#
#    year_times_loudness  year_times_popularity  year_times_valence
# 0            -24245.76                  23040            1217.280
# 1            -13941.12                  13440            1824.000
# 2            -23228.16                   7680            1322.880
# 3            -14037.12                  32640              81.024
# 4            -11589.12                   3840             574.080
#
# [5 rows x 38 columns]

# %% [markdown]
# W celu lepszej wizualizacji zależności pomiędzy cechami a rokiem wylosowano 5% próbek, które przedstawiono na wykresach z uwagi, że 100% populacji dawało nieczytelny obraz.

# %%
plt.figure(figsize=(5,5*len(new_features)))
all_features_data = music.drop(['energy'], axis = 1)
big_music_data, small_music_data, years_big, years_small = train_test_split(all_features_data, music['energy'], test_size=0.05, random_state=1)
for i, feature in enumerate(new_features):
    plt.subplot(len(new_features), 1, i+1)
    m,b = np.polyfit(small_music_data[feature], years_small,1)
    plt.title('cecha: ' + feature + '; równanie prostej dopasowanej: y =' + str(m) +'* x +' + str(b) )
    plt.plot(small_music_data[feature], m * small_music_data[feature] + b, color = 'red')
    plt.scatter(small_music_data[feature], years_small)
# Out:
# /usr/lib/python3/dist-packages/matplotlib/cbook/__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   ndim = x[:, None].ndim
# /usr/lib/python3/dist-packages/matplotlib/axes/_base.py:276: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# /usr/lib/python3/dist-packages/matplotlib/axes/_base.py:278: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]

# %% [markdown]
# Na tej podstawie można wnioskować, że cecha *log_instrumentalness* i *year_times_valence* została nietrafnie stworzona i nie bedzie brała udziału w uczeniu, natomiast widać pewną relację liniową w cesze *year_times_acousticness* czy *square_acousticness*, które prawdopodobnie będą miały spory udział w uczeniu.

# %% [markdown]
# ### Wybór cech modelu regresji
#
# Poniższa sekcja przedstawia cechy wybrane przez różne automatyczne metody doboru cech.
#
# Na początku jednak rozróżnione zostaną cechy wejściowe od wyjsciowych oraz zostanie podzielony zbiór na dane testowe i treningowe

# %%
output_feature = 'energy'
input_features = music.columns.tolist()
input_features.remove(output_feature)
X_train, X_test, y_train, y_test = train_test_split(music[input_features], music['energy'], test_size=0.33, random_state=1)

# %% [markdown]
# 1. Metoda regularyzacji Lasso

# %%
λ = [0.0, 0.00000001]
λ_treshold = 0.001
factor = 2.0
while λ[-1] * factor < λ_treshold:
    λ.append(λ[-1] * factor)
if λ[-1] != λ_treshold:
    λ.append(λ_treshold)

train_error = []
test_error = []

for item in λ:
    model = linear_model.Lasso(alpha=item, normalize=True)
    estimator = cross_validate(model, X_train[input_features], y_train, return_estimator=True)
    train_error.append(np.mean([mean_squared_error(y_train, estim.predict(X_train[input_features]), squared=False) for estim in estimator['estimator']]))
    test_error.append(np.mean([mean_squared_error(y_test, estim.predict(X_test[input_features]), squared=False) for estim in estimator['estimator']]))
plt.scatter(λ, train_error)
plt.scatter(λ, test_error)
# Out:
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:515: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:474: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:474: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 598.8383163898824, tolerance: 0.6953555084765375
#   model = cd_fast.enet_coordinate_descent(
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:515: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:474: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:474: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 590.4430501222653, tolerance: 0.6943033184129311
#   model = cd_fast.enet_coordinate_descent(
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:515: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:474: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:474: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 597.4663320828408, tolerance: 0.6934745622428988
#   model = cd_fast.enet_coordinate_descent(
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:515: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:474: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:474: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 595.4780617981954, tolerance: 0.692520591615216
#   model = cd_fast.enet_coordinate_descent(
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:515: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:474: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:474: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 595.7681226485299, tolerance: 0.6910898155947773
#   model = cd_fast.enet_coordinate_descent(
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:474: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 567.255563408012, tolerance: 0.6953555084765375
#   model = cd_fast.enet_coordinate_descent(
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:474: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 559.0080146720002, tolerance: 0.6943033184129311
#   model = cd_fast.enet_coordinate_descent(
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:474: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 567.5353879524763, tolerance: 0.6934745622428988
#   model = cd_fast.enet_coordinate_descent(
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:474: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 564.5845296137876, tolerance: 0.692520591615216
#   model = cd_fast.enet_coordinate_descent(
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:474: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 564.590240140896, tolerance: 0.6910898155947773
#   model = cd_fast.enet_coordinate_descent(
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:474: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 536.6273839137699, tolerance: 0.6953555084765375
#   model = cd_fast.enet_coordinate_descent(
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:474: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 528.6883507149397, tolerance: 0.6943033184129311
#   model = cd_fast.enet_coordinate_descent(
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:474: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 538.8094234920227, tolerance: 0.6934745622428988
#   model = cd_fast.enet_coordinate_descent(
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:474: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 534.793107828257, tolerance: 0.692520591615216
#   model = cd_fast.enet_coordinate_descent(
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:474: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 534.512987246364, tolerance: 0.6910898155947773
#   model = cd_fast.enet_coordinate_descent(
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:474: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 477.8728738503255, tolerance: 0.6953555084765375
#   model = cd_fast.enet_coordinate_descent(
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:474: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 470.7174441031384, tolerance: 0.6943033184129311
#   model = cd_fast.enet_coordinate_descent(
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:474: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 483.69090001848684, tolerance: 0.6934745622428988
#   model = cd_fast.enet_coordinate_descent(
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:474: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 477.8267722465022, tolerance: 0.692520591615216
#   model = cd_fast.enet_coordinate_descent(
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:474: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 476.98676302773544, tolerance: 0.6910898155947773
#   model = cd_fast.enet_coordinate_descent(
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:474: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 413.4368751180631, tolerance: 0.6953555084765375
#   model = cd_fast.enet_coordinate_descent(
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:474: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 405.60295536669656, tolerance: 0.6943033184129311
#   model = cd_fast.enet_coordinate_descent(
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:474: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 418.19019714623494, tolerance: 0.6934745622428988
#   model = cd_fast.enet_coordinate_descent(
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:474: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 412.4750020390196, tolerance: 0.692520591615216
#   model = cd_fast.enet_coordinate_descent(
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:474: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 414.4397293184046, tolerance: 0.6910898155947773
#   model = cd_fast.enet_coordinate_descent(
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:474: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 338.18608705879933, tolerance: 0.6953555084765375
#   model = cd_fast.enet_coordinate_descent(
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:474: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 333.5042284845692, tolerance: 0.6943033184129311
#   model = cd_fast.enet_coordinate_descent(
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:474: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 343.7076981106016, tolerance: 0.6934745622428988
#   model = cd_fast.enet_coordinate_descent(
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:474: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 339.10123390948144, tolerance: 0.692520591615216
#   model = cd_fast.enet_coordinate_descent(
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:474: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 340.47849257935854, tolerance: 0.6910898155947773
#   model = cd_fast.enet_coordinate_descent(
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:474: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 103.79289421981639, tolerance: 0.6953555084765375
#   model = cd_fast.enet_coordinate_descent(
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:474: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 97.26014998992753, tolerance: 0.6943033184129311
#   model = cd_fast.enet_coordinate_descent(
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:474: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 108.65325199254187, tolerance: 0.6934745622428988
#   model = cd_fast.enet_coordinate_descent(
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:474: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 102.00995605801938, tolerance: 0.692520591615216
#   model = cd_fast.enet_coordinate_descent(
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:474: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 104.92966852859934, tolerance: 0.6910898155947773
#   model = cd_fast.enet_coordinate_descent(
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:474: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6.134013190690439, tolerance: 0.6953555084765375
#   model = cd_fast.enet_coordinate_descent(
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:474: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5.302311999412041, tolerance: 0.6943033184129311
#   model = cd_fast.enet_coordinate_descent(
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:474: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7.25024733232658, tolerance: 0.6934745622428988
#   model = cd_fast.enet_coordinate_descent(
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:474: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5.801456329208122, tolerance: 0.692520591615216
#   model = cd_fast.enet_coordinate_descent(
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:474: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6.802528262758642, tolerance: 0.6910898155947773
#   model = cd_fast.enet_coordinate_descent(
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:474: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.7801244658905944, tolerance: 0.6953555084765375
#   model = cd_fast.enet_coordinate_descent(
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:474: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.4610163734189427, tolerance: 0.6943033184129311
#   model = cd_fast.enet_coordinate_descent(
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:474: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.063618014192116, tolerance: 0.6934745622428988
#   model = cd_fast.enet_coordinate_descent(
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:474: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.7087865847636294, tolerance: 0.692520591615216
#   model = cd_fast.enet_coordinate_descent(
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:474: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.9380699393859686, tolerance: 0.6910898155947773
#   model = cd_fast.enet_coordinate_descent(
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:474: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.7353677691689882, tolerance: 0.6953555084765375
#   model = cd_fast.enet_coordinate_descent(
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:474: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.7136644589111256, tolerance: 0.6934745622428988
#   model = cd_fast.enet_coordinate_descent(
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:474: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.6922348909902212, tolerance: 0.6910898155947773
#   model = cd_fast.enet_coordinate_descent(
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:474: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.6663745918999666, tolerance: 0.6953555084765375
#   model = cd_fast.enet_coordinate_descent(
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:474: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.9878631839146692, tolerance: 0.6943033184129311
#   model = cd_fast.enet_coordinate_descent(
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:474: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.779341635375431, tolerance: 0.6934745622428988
#   model = cd_fast.enet_coordinate_descent(
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:474: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.9604030078514825, tolerance: 0.692520591615216
#   model = cd_fast.enet_coordinate_descent(
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:474: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.8439473112764517, tolerance: 0.6910898155947773
#   model = cd_fast.enet_coordinate_descent(
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:474: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.0604349090961023, tolerance: 0.6953555084765375
#   model = cd_fast.enet_coordinate_descent(
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:474: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.3306722693469055, tolerance: 0.6943033184129311
#   model = cd_fast.enet_coordinate_descent(
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:474: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.0228160340041086, tolerance: 0.6934745622428988
#   model = cd_fast.enet_coordinate_descent(
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:474: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.18092698297869, tolerance: 0.692520591615216
#   model = cd_fast.enet_coordinate_descent(
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:474: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.137138967350893, tolerance: 0.6910898155947773
#   model = cd_fast.enet_coordinate_descent(

# %% [markdown]
# Na podstawie powyższej analizy metoda Lasso wskazała, że do procesu nauki powinniśmy wykorzystać wszystkie zmienne.

# %% [markdown]
# 2. Metoda Forward Stepwise

# %%
lr = LinearRegression()
errors_train = []
errors_test = []
features =  input_features.copy()
features_copy =  input_features.copy()
temp_features = []

for i in range(len(features)):
    temp_error = float("inf")
    if len(temp_features) != 0:
        temp_error = 1.0 - np.mean(cross_val_score(lr, X_train[temp_features].to_numpy(), y_train.to_numpy(), cv=5))
    temp_index = -1
    new_temp_error = float("inf") # błąd modelu z nową cechą
    for j, value in enumerate(features_copy):
        temp_features.append(value)
        error = 1.0 - np.mean(cross_val_score(lr, X_train[temp_features].to_numpy(), y_train.to_numpy(), cv=5))
        if(error < new_temp_error):
            temp_index = j
            new_temp_error = error
        del temp_features[-1]
    if new_temp_error < temp_error:
        temp_error = new_temp_error
        temp_features.append(features_copy[temp_index])
        del features_copy[temp_index]
        errors_train.append(1.0 - np.mean(cross_val_score(lr, X_train[temp_features].to_numpy(), y_train.to_numpy(), cv=5)))
        errors_test.append(1.0 - np.mean(cross_val_score(lr, X_test[temp_features].to_numpy(), y_test.to_numpy(), cv=5)))
    else:
        break
plt.plot(range(len(temp_features)), errors_train)
plt.plot(range(len(temp_features)), errors_test)
print("Wybrane cechy: ", temp_features)
print("Liczba cech: ", len(temp_features))
print("Błąd uczenia: ", 1.0 - np.mean(cross_val_score(lr, X_train[temp_features].to_numpy(), y_train.to_numpy(),cv=5)))
print("Błąd testowania: ", 1.0 - np.mean(cross_val_score(lr, X_test[temp_features].to_numpy(), y_test.to_numpy(), cv=5)))
      
forward_stepwise_features = temp_features.copy()
# Out:
# Wybrane cechy:  ['loudness_times_acousticness', 'loudness', 'acousticness', 'square_valence', 'liveness', 'log_instrumentalness', 'danceability', 'cube_loudness', 'valence_times_acousticness', 'cube_acousticness', 'square_acousticness', 'cube_popularity', 'valence_times_popularity', 'log_speechiness', 'speechiness', 'explicit', 'year', 'cube_year', 'square_year', 'square_popularity', 'mode', 'duration_ms', 'tempo', 'year_times_acousticness', 'log_liveness', 'instrumentalness', 'cube_valence', 'popularity_times_acousticness', 'year_times_popularity', 'popularity', 'square_loudness', 'year_times_loudness', 'key', 'valence_times_loudness']
# Liczba cech:  34
# Błąd uczenia:  0.16970845338535212
# Błąd testowania:  0.16681647717492343

# %% [markdown]
# 3. Metoda Backward Stepwise

# %%
lr = LinearRegression()
errors_train = []
errors_test = []
features =  input_features.copy()
features_copy =  input_features.copy()
temp_features = input_features.copy()

for i in range(len(features)):
    temp_error = float("inf")
    if len(temp_features) != 0:
        temp_error = 1.0 - np.mean(cross_val_score(lr, X_train[temp_features].to_numpy(), y_train.to_numpy(), cv=5))
    temp_index = -1
    new_temp_error = float("inf") # błąd modelu z nową cechą
    for j, value in enumerate(features_copy):
        temp_features.remove(value)
        error = 1.0 - np.mean(cross_val_score(lr, X_train[temp_features].to_numpy(), y_train.to_numpy(), cv=5))
        if(error < new_temp_error):
            temp_index = j
            new_temp_error = error
        temp_features.append(value)
    if new_temp_error < temp_error:
        temp_error = new_temp_error
        temp_features.remove(features_copy[temp_index])
        del features_copy[temp_index]
        errors_train.append(1.0 - np.mean(cross_val_score(lr, X_train[temp_features].to_numpy(), y_train.to_numpy(), cv=5)))
        errors_test.append(1.0 - np.mean(cross_val_score(lr, X_test[temp_features].to_numpy(), y_test.to_numpy(), cv=5)))
    else:
        break
print("Wybrane cechy: ", temp_features)
print("Liczba wybranych cech: ", len(temp_features))
print("Błąd uczenia: ", 1.0 - np.mean(cross_val_score(lr, X_train[temp_features].to_numpy(), y_train.to_numpy(), cv=5)))
print("Błąd testowania: ", 1.0 - np.mean(cross_val_score(lr, X_test[temp_features].to_numpy(), y_test.to_numpy(), cv=5)))

backward_stepwise_features = temp_features.copy()
# Out:
# Wybrane cechy:  ['danceability', 'duration_ms', 'explicit', 'instrumentalness', 'key', 'liveness', 'loudness', 'mode', 'popularity', 'speechiness', 'tempo', 'valence', 'year', 'log_instrumentalness', 'log_liveness', 'log_speechiness', 'cube_acousticness', 'square_acousticness', 'cube_loudness', 'square_loudness', 'loudness_times_acousticness', 'cube_popularity', 'square_popularity', 'cube_valence', 'valence_times_acousticness', 'valence_times_loudness', 'valence_times_popularity', 'cube_year', 'square_year', 'year_times_acousticness', 'year_times_loudness', 'year_times_popularity', 'year_times_valence']
# Liczba wybranych cech:  33
# Błąd uczenia:  0.16969279700953965
# Błąd testowania:  0.16671802610671982

# %% [markdown]
# 4. Metoda każdy z każdym

# %%
lr = LinearRegression()
errors_train = []
errors_test = []
features =  input_features.copy()
features_copy =  input_features.copy()
temp_features = input_features.copy()
brute_force_features = []
global_min_error = float("inf")



for i in range(len(features)):
    temp_error = float("inf")
    temp_index = -1
    for j, value in enumerate(features_copy):
        temp_features.append(value)
        error = 1.0 - np.mean(cross_val_score(lr, X_train[temp_features].to_numpy(), y_train.to_numpy(), cv=5))
        if(error < temp_error):
            if (error < global_min_error):
                global_min_error = error
                brute_force_features = temp_features.copy()
            temp_index = j
            temp_error = error
        del temp_features[-1]
    temp_features.append(features_copy[temp_index])
    del features_copy[temp_index]
    errors_train.append(1.0 - np.mean(cross_val_score(lr, X_train[temp_features].to_numpy(), y_train.to_numpy(), cv=5)))
    errors_test.append(1.0 - np.mean(cross_val_score(lr, X_test[temp_features].to_numpy(), y_test.to_numpy(), cv=5)))
plt.figure()
plt.ylabel("Błędy uczenia")
plt.plot(range(1, len(features)+1), errors_train)
plt.xlabel("Ilość wziętych pod uwagę kolejnych cech")

plt.figure()
plt.ylabel("Błędy walidacji")
plt.plot(range(1, len(features)+1), errors_test)
plt.xlabel("Ilość wziętych pod uwagę kolejnych cech")
print("kolejne cechy: ", temp_features)
# Out:
# kolejne cechy:  ['acousticness', 'danceability', 'duration_ms', 'explicit', 'instrumentalness', 'key', 'liveness', 'loudness', 'mode', 'popularity', 'speechiness', 'tempo', 'valence', 'year', 'log_instrumentalness', 'log_liveness', 'log_speechiness', 'cube_acousticness', 'square_acousticness', 'cube_loudness', 'square_loudness', 'loudness_times_acousticness', 'cube_popularity', 'square_popularity', 'popularity_times_acousticness', 'popularity_times_loudness', 'cube_valence', 'square_valence', 'valence_times_acousticness', 'valence_times_loudness', 'valence_times_popularity', 'cube_year', 'square_year', 'year_times_acousticness', 'year_times_loudness', 'year_times_popularity', 'year_times_valence', 'cube_popularity', 'speechiness', 'acousticness', 'log_instrumentalness', 'log_speechiness', 'valence_times_acousticness', 'popularity', 'year_times_popularity', 'log_liveness', 'square_popularity', 'instrumentalness', 'cube_acousticness', 'liveness', 'cube_valence', 'loudness_times_acousticness', 'mode', 'square_valence', 'cube_year', 'year_times_loudness', 'year_times_acousticness', 'explicit', 'loudness', 'popularity_times_loudness', 'square_loudness', 'valence', 'cube_loudness', 'tempo', 'danceability', 'duration_ms', 'square_year', 'square_acousticness', 'year', 'year_times_valence', 'valence_times_popularity', 'valence_times_loudness', 'popularity_times_acousticness', 'key']

# %% [markdown]
# Wnioski:
# * widoczny jest fakt, że model wymaga dużej liczby cech do prawidłowego działania, na co wskazała każda automatyczna metoda doboru cech
# * w porównaniu do liczby użytych próbek cech jest dużo mniej co może sprawić, że nie wykorzystamy w pełni potencjału tak dużego zbioru danych
# * dodanie kolejnych cech sprawia, że wzmocnione zostaje wnioskowanie modelu regresji jednak brak dużej ilości dobrze skorelowanych z wyjściem cech nie pozwoli na osiągnięcie dobrego estymowania energii z niską wartością błędu

# %% [markdown]
# ### Trenowanie modeli

# %% [markdown]
# Przygotowano metodę przy pomocy, której zostanie policzony błąd każdego modelu regresji wielorakiej

# %%
def measureModel(X_train, y_train, X_test, y_test):
    X_pinv = np.linalg.pinv(X_train)
    ω = np.dot(X_pinv, y_train)
    y_pred_train = np.dot(X_train, ω)
    train_error = mean_squared_error(y_train, y_pred_train, squared=False)
    y_pred_test = np.dot(X_test, ω)
    test_error = mean_squared_error(y_test, y_pred_test, squared=False)
    print('Train error: ' + str(train_error), ", Test error: " + str(test_error))
    return train_error, test_error

train_error = []
test_error = []

# %% [markdown]
# Model składający się ze wszystkich cech (Lasso)

# %%
tr_error, ts_error = measureModel(X_train, y_train, X_test, y_test)
train_error.append(tr_error)
test_error.append(ts_error)
# Out:
# Train error: 0.11265459359737516 , Test error: 0.11177413938105052

# %% [markdown]
# Model z cechami dobranymi metodą w przód

# %%
tr_error, ts_error  =  measureModel(X_train[forward_stepwise_features], y_train, X_test[forward_stepwise_features], y_test)
train_error.append(tr_error)
test_error.append(ts_error)
# Out:
# Train error: 0.11265636065041162 , Test error: 0.11178502652193512

# %% [markdown]
# Model z cechami dobranymi metodą w tył

# %%
tr_error, ts_error = measureModel(X_train[backward_stepwise_features], y_train, X_test[backward_stepwise_features], y_test)
train_error.append(tr_error)
test_error.append(ts_error)
# Out:
# Train error: 0.11265682675589912 , Test error: 0.1117691797069049

# %% [markdown]
# Model z cechami dobranymi metodą każdy z każdym

# %%
brute_force_model = measureModel(X_train[brute_force_features], y_train, X_test[brute_force_features], y_test)
# Out:
# Train error: 0.11265459359757823 , Test error: 0.11177414361192965

# %%
kolumny = [
    'wszystkie cechy (Lasso)',
    'forward stepwise',
    'backward stepwise',
    'brute force'
]


plt.figure(figsize=(15, 10))
for i, elem in enumerate(train_error):
    plt.ylabel("Błąd MSE")
    plt.xlabel("Wybrane modele")
    plt.scatter(kolumny[i], train_error[i], c = 'green')
    plt.scatter(kolumny[i], test_error[i], c = 'red')   


import matplotlib.patches as mpatches
import matplotlib.pyplot as plt

red_patch = mpatches.Patch(color='red', label='Błędy testowania')
green_patch = mpatches.Patch(color='green', label='Błędy uczenia')

plt.legend(handles=[red_patch, green_patch])

# %% [markdown]
# Wnioski:
# * Model regresji wielorakiej zwraca bardzo zbliożone wyniki dla każdego z wyznaczonych zestawu cech
# * Błędy dla zbioru testowego są mniejsze niż w przypadku zbioru uczelnia. Pokazuje to, że model nie jest w stanie douczyć się do zadanego problemu. Wybrane cechy nie są dostatecznie dobrze skorelowane ze zmienną przewidywaną

# %% [markdown]
# ## Regularyzacja dla najlepszego modelu

# %% [markdown]
# ### Dobranie współczynnika regularyzacji dla metody grzbietowej

# %%
from sklearn.linear_model import Ridge
from sklearn.model_selection import cross_validate
from sklearn.metrics import mean_squared_error

backward_stepwise_features = ['danceability', 'duration_ms', 'explicit', 'instrumentalness', 'key', 'liveness', 'loudness', 'mode', 'popularity', 'speechiness', 'tempo', 'valence', 'year', 'log_instrumentalness', 'log_liveness', 'log_speechiness', 'cube_acousticness', 'square_acousticness', 'cube_loudness', 'square_loudness', 'loudness_times_acousticness', 'cube_popularity', 'square_popularity', 'cube_valence', 'valence_times_acousticness', 'valence_times_loudness', 'valence_times_popularity', 'cube_year', 'square_year', 'year_times_acousticness', 'year_times_loudness', 'year_times_popularity', 'year_times_valence']

ridge_alpha = [0.0, 0.001]
for i in range(15):
    ridge_alpha.append(ridge_alpha[-1] * 2)
    
print("Zostają rozpatrzone współczynniki:")
print(ridge_alpha)

train_error = []

for alpha in ridge_alpha:
    model = Ridge(alpha = alpha)
    scores = cross_validate(model, X_train[backward_stepwise_features], y_train, return_estimator=True)
    mse_train = 0
    for i in range(0, 5):
        mse_train += mean_squared_error(y_train, scores['estimator'][i].predict(X_train[backward_stepwise_features]), squared=False)
    mse_train /= 5
    train_error.append(mse_train)

plt.figure(figsize=(15, 5), dpi= 80)
plt.xlabel("alpha")
plt.ylabel("mse")
plt.title("błąd uczenia")
plt.scatter(ridge_alpha, train_error)

print("Najmniejszy błąd uczenia dla współczynnika regularyzacji:")
print(ridge_alpha[train_error.index(min(train_error))])
# Out:
# Zostają rozpatrzone współczynniki:
# [0.0, 0.001, 0.002, 0.004, 0.008, 0.016, 0.032, 0.064, 0.128, 0.256, 0.512, 1.024, 2.048, 4.096, 8.192, 16.384, 32.768]
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.4534e-23): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.44975e-23): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.44493e-23): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.4574e-23): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.45473e-23): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.46374e-23): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.4601e-23): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.45522e-23): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.46772e-23): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.46508e-23): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.47409e-23): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.47046e-23): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.46551e-23): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.47803e-23): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.47542e-23): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.49478e-23): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.49116e-23): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.48608e-23): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.49866e-23): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.49612e-23): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.53617e-23): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.53258e-23): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.52725e-23): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.53993e-23): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.53752e-23): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.61899e-23): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.61546e-23): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.60963e-23): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.62251e-23): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.62037e-23): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.7848e-23): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.78138e-23): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.77456e-23): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.78783e-23): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.78624e-23): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=2.11701e-23): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=2.11383e-23): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=2.10503e-23): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=2.11907e-23): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=2.1186e-23): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=2.78338e-23): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=2.78067e-23): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=2.76806e-23): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=2.78349e-23): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=2.7854e-23): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=4.12176e-23): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=4.12004e-23): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=4.10005e-23): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=4.11798e-23): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=4.125e-23): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=6.81201e-23): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=6.81226e-23): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=6.77811e-23): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=6.8003e-23): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=6.81838e-23): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.22189e-22): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.2223e-22): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.21613e-22): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.21908e-22): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.22326e-22): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=2.30803e-22): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=2.30918e-22): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=2.29752e-22): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=2.30174e-22): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=2.31095e-22): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=4.48918e-22): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=4.49173e-22): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=4.46889e-22): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=4.47546e-22): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=4.49527e-22): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=8.86713e-22): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=8.87297e-22): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=8.82662e-22): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=8.83813e-22): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=8.88016e-22): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.7648e-21): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.76599e-21): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.75661e-21): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.75861e-21): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.73166e-21): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=3.52411e-21): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=3.5264e-21): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=3.50756e-21): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=3.51111e-21): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# /home/edsuch21/.local/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=3.5295e-21): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# Najmniejszy błąd uczenia dla współczynnika regularyzacji:
# 0.0

# %% [markdown]
# Wnioski:
# * Powyższe badanie pokazuje, że regularyzacja nie poprawia wyników modelu.
# * Otrzymane wartości błędów modelu nie są spowodowane wariancją zebranych danych, a najprawdopodobniej wybrane cechy nie są wystarczająco skorelowane ze zmienną estymowaną.

# %% [markdown]
# ### Przyjęta hipoteza: "*Istnieje możliwość szacowania energii muzyki na podstawie jej cech*" zostaje obalona.
